# %% [markdown]
# # Python Operator

# %%
x, y = 10, 5

# %%
x+y
# Out:
# 15

# %%
x-y
# Out:
# 5

# %%
x*y
# Out:
# 50

# %%
x//y
# Out:
# 2

# %%
x/y
# Out:
# 2.0

# %%
x**y
# Out:
# 100000

# %% [markdown]
# # ASSIGNMENT OPERATOR

# %%
x
# Out:
# 10

# %%
x+=2

# %%
x
# Out:
# 12

# %%
x+=2

# %%
x
# Out:
# 14

# %%
x *=2

# %%
x
# Out:
# 56

# %%
x //=2
x
# Out:
# 3

# %%
x /=2

# %%
x
# Out:
# 1.5

# %% [markdown]
# # Unary Operator

# %%
n = 7 #negattion
n
# Out:
# 7

# %%
m=-n
m
# Out:
# -7

# %% [markdown]
# # Relational Operator(we are using this for comparing)

# %%
a=5
b=6

# %%
a<b
# Out:
# True

# %%
a>b
# Out:
# False

# %%
a==b
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
b=5
b
# Out:
# 5

# %%
a==b
# Out:
# True

# %%
a!=b
# Out:
# False

# %%
print(a)
print(b)
# Out:
# 5
# 5

# %%
b=7
b
# Out:
# 7

# %%
print(a)
print(b)
# Out:
# 5
# 7

# %%
a>=b
# Out:
# False

# %%
a<=b
# Out:
# True

# %% [markdown]
# # Logical Operator

# %%
a=5
b=4

# %%
a<8 and b<5
# Out:
# True

# %%
a<8 or b<5
# Out:
# True

# %%
a >8 and b > 5
# Out:
# False

# %%
a >8 or b > 5
# Out:
# False

# %%
x1 = False
x1
# Out:
# False

# %%
y1 = not x1
y1
# Out:
# True

# %% [markdown]
# # Print()

# %% [raw]
# # print is use for answer

# %%
a=10
b=20
a
b
# Out:
# 20

# %%
a=10
b=20
print(a)
print(b)
# Out:
# 10
# 20

# %%
num1=20 num2=30
add=num1+num2
print(add)
# Out:
#   Cell In[74], line 1
#     num1=20 num2=30
#             ^
# SyntaxError: invalid syntax

# %%
print(10) 
print(10,20)
print('python') 
print(10,20,'python') 
print(2, 2.3, 'nit', True, 1+2j)
# Out:
# 10
# 10 20
# python
# 10 20 python
# 2 2.3 nit True (1+2j)

# %%
num1=20
num2=30
add=num1+num2 
print(add)
# Out:
# 50

# %%
num1, num2 = 20, 30
add = num1 + num2  
print(add)
# Out:
# 50

# %% [markdown]
# # Print result with String

# %%
num1=20 
num2=30 
add=num1+num2
print('The addition of',num1,'and',num2,'is=',add)
# Out:
# The addition of 20 and 30 is= 50

# %%
name='Python'
age=20
city='hyd'
#hellow my name is python and i am 10 year old from hydrabad

# %%
print('My name is',name,'and i am',age,'years old form',city)
# Out:
# My name is Python and i am 20 years old form hyd

# %% [markdown]
# ### print Format method

# %%
num1=20 
num2=30
add=num1+num2

print('The addition of {} and {} is= {}'.format(num1,num2,add))
# Out:
# The addition of 20 and 30 is= 50

# %% [markdown]
# ![Screenshot 2026-04-07 165216.png](attachment:9c3a1268-d683-446c-a529-9a002a945a3d.png)

# %%
name='Python'
age=20
city='hyd'
#hellow my name is python and i am 10 year old from hydraba

# %%
print('hello my name is {}, and i am {} years old from {}'.format(name,age,city))
# Out:
# hello my name is Python, and i am 20 years old from hyd

# %%
num1=100
num2=25
num3=333
avg=(num1+num2+num3)/3 # or we can use avg=round(num1+num2+num3)/3,2)
avg1=round((num1+num2+num3)/3,2)
# The avrage of num1,num2,num3 is = avg
print('The avrage of {}, {}, and {} is= {} or {}'.format(num1,num2,num3,
avg,avg1)) # here we can use round(avg,2) also
# Out:
# The avrage of 100, 25, and 333 is= 152.66666666666666 or 152.67

# %%
round(avg,2) # round of till 2 digite after decimal
# Out:
# 152.67

# %% [markdown]
#   ![Screenshot 2026-04-07 165817.png](attachment:940d071e-ca65-4e11-965c-7742dfbbdd00.png)

# %%
num1=20
num2=30
add=num1+num2
print(f'The addition of {num1} and {num2} is= {add}') # alwase prefer this
# Out:
# The addition of 20 and 30 is= 50

# %%
name='Python'
age=20
city='hyd'
#hellow my name is python and i am 10 year old from hydrabad

# %%
print(f'hello my name is {name}, and i am {age} year old, from {city}.')
# Out:
# hello my name is Python, and i am 20 year old, from hyd.

# %%
um1=100
num2=25
num3=333
avg=round((num1+num2+num3)/3,2) # or we can use avg=round(num1+num2+num3)/3,2)
# The avrage of num1,num2,num3 is = avg

# %%
print(f'The avrage of {num1}, {num2} and {num3} is = {avg}')

# %%
# lete combine all
num1=10
num2=20
add = num1+ num2
print('The addition of',num1,'and',num2,'is=',add)
print('The addition of {} and {} is= {}'.format(num1,num2,add))
print(f'The addition of {num1} and {num2} is= {add}')
# Out:
# The addition of 10 and 20 is= 30
# The addition of 10 and 20 is= 30
# The addition of 10 and 20 is= 30

# %% [markdown]
# # End Statement

# %%
print('hello') # 1st statement
print('good moorning') # 2nd statement)
# i want print like:- hellow good morning
# Out:
# hello
# good moorning

# %%
print('hello', end=' ') # 1st statement
print('world good day') # 2nd statement
# Out:
# hello world good day

# %% [markdown]
# ![Screenshot 2026-04-07 170743.png](attachment:95cd6361-376a-4c46-923d-43359de8911e.png)

# %%
print('hello','hai','how are you',sep='--->')
# Out:
# hello--->hai--->how are you

# %%
print('hello','hai','how are you',sep='&')
# Out:
# hello&hai&how are you

# %%
print('hello','hai','how are you',sep='@')
# Out:
# hello@hai@how are you

# %%
print('hello','hai','how are you',sep=' ')
# Out:
# hello hai how are you

# %%
print(3,'.') # . is far from 3 so here we will use sep method
# Out:
# 3 .

# %%
print(3,'.',sep='') # see now space setteld(also use to remove space B/W words)
# Out:
# 3.

# %%
print(1,2,end=' ')
print(3,'.',sep='')
# will print 1 2 3.
# Out:
# 1 2 3.
